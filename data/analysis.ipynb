# %%
import pandas as pd

df_long_500 = pd.read_csv("long-500.csv")
df_short_500 = pd.read_csv("short-500.csv")

# %%
len(df_long_500), len(df_short_500)
# Out:
# (500, 500)

# %%
df_long_500["narrative"].str.split().str.len().describe(percentiles=[.25, .5, .75, .95])
# Out:
# count     500.000000
# mean      243.036000
# std       171.358753
# min       109.000000
# 25%       159.000000
# 50%       195.000000
# 75%       268.250000
# 95%       489.300000
# max      2317.000000
# Name: narrative, dtype: float64

# %%
df_short_500["narrative"].str.split().str.len().describe(percentiles=[.25, .5, .75, .95])
# Out:
# count    500.000000
# mean      23.408000
# std       10.366507
# min        4.000000
# 25%       15.000000
# 50%       23.000000
# 75%       32.000000
# 95%       39.000000
# max       46.000000
# Name: narrative, dtype: float64

# %%
df_long_500["product"].value_counts()
# Out:
# product
# credit_reporting       168
# mortgages_and_loans    119
# credit_card             77
# debt_collection         73
# retail_banking          63
# Name: count, dtype: int64

# %%
df_short_500["product"].value_counts()
# Out:
# product
# credit_reporting       270
# debt_collection         95
# retail_banking          49
# mortgages_and_loans     43
# credit_card             43
# Name: count, dtype: int64
